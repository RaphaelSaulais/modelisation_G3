# %%
# %run building_model_Vfinal.py
# Out:
# σ = 5.67e-08 W/(m²⋅K⁴)
# θss = [10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10.
#  10.] °C
# θssQ = [0.01 0.03 0.05 0.49 0.93 0.17 0.97 0.1  0.65 0.37 0.35 0.34 0.32 0.3
#  0.16 0.02 0.01 0.   0.94] °C
# uss = [10 10 10 20 10 10  0  0  0  0  0]
# yss = 10.00 °C
# Error between DAE and state-space: 0.00e+00 °C
# yssQ = 10.97 °C
# Error between DAE and state-space: 1.00e+01 °C
# dtmax = 249 s = 4.2 min
# dt = 240 s = 4.0 min
# t_settle = 826517 s = 229.6 h
# duration = 828000 s = 230.0 h
# Steady-state indoor temperature obtained with:
# - DAE model: 10.0000 °C
# - state-space model: 10.0000 °C
# - steady-state response to step input: 9.9996 °C
# Steady-state indoor temperature obtained with:
# - DAE model: 0.9659 °C
# - state-space model: 10.9659 °C
# - steady-state response to step input: 11.2547 °C
# dt = 240 s = 4.0 min
